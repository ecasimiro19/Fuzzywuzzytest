# %%
import pandas as pd
from fuzzymatch import check_match

# %%
cities1 = pd.read_excel("California Cities- 2017 Pop.xlsx")

# %%
cities1.set_index('pol1', inplace=True)

# %%
cities2 = pd.read_csv('PEP_2017_PEPANNRES_with_ann.csv', encoding='latin1')

# %%
df = cities2["GEO.display-label"].str.split(",", n = 1, expand = True)

# %%
df.columns=['name', 'state']

# %%
df.set_index('name', inplace=True)

# %%
left, right = check_match(cities1, df)

# %%
len(left)
# Out:
# 482

# %%
len(right)
# Out:
# 483

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 483 entries, Geography to Yucca Valley town
# Data columns (total 1 columns):
# state    482 non-null object
# dtypes: object(1)
# memory usage: 7.5+ KB

# %%
import fuzzymatcher

# %%
cities1
# Out:
#            County             pol1  Population Estimate 2017  pol2  pol3  \
# 0         Alameda          Alameda                     79177     1   1.0
# 1         Alameda           Albany                     20143     1   1.0
# 2         Alameda         Berkeley                    122324     1   1.0
# 3         Alameda           Dublin                     60939     0   NaN
# 4         Alameda       Emeryville                     11758     1   1.0
# 5         Alameda          Fremont                    234962     1   1.0
# 6         Alameda          Hayward                    160500     1   1.0
# 7         Alameda        Livermore                     90295     0   NaN
# 8         Alameda           Newark                     47531     1   1.0
# 9         Alameda          Oakland                    425195     1   1.0
# 10        Alameda         Piedmont                     11378     1   1.0
# 11        Alameda       Pleasanton                     83007     0   NaN
# ...

# %%
df = fuzzymatcher.fuzzy_left_join(cities1, cities2, left_on = "pol1", right_on = "GEO.display-label")

# %%
df[['pol1', 'GEO.display-label']]
# Out:
#                 pol1                            GEO.display-label
# 0            Alameda                     Alameda city, California
# 1             Albany                      Albany city, California
# 2           Berkeley                    Berkeley city, California
# 3             Dublin                      Dublin city, California
# 4         Emeryville                  Emeryville city, California
# 5            Fremont                     Fremont city, California
# 6            Hayward                     Hayward city, California
# 7          Livermore                   Livermore city, California
# 8             Newark                      Newark city, California
# 9            Oakland                     Oakland city, California
# 10          Piedmont                    Piedmont city, California
# 11        Pleasanton                  Pleasanton city, California
# 12       San Leandro                 San Leandro city, California
# ...

# %%
df[df['GEO.display-label'].duplicated(keep=False)]
# Out:
#      best_match_score __id_left __id_right       County             pol1  \
# 84          -0.024214   83_left   32_right         Kern  California City
# 159          0.143525  106_left   32_right  Los Angeles             Bell
#
#      Population Estimate 2017  pol2  pol3                 pol4  pol5  ...  \
# 84                      13972     1   0.0  2730-04-18 00:00:00   NaN  ...
# 159                     35811     0   NaN                  NaN   NaN  ...
#
#     rescen42010 resbase42010 respop72010  respop72011 respop72012  \
# 84        35477        35473       35494        35684       35843
# 159       35477        35473       35494        35684       35843
#
#      respop72013  respop72014  respop72015  respop72016 respop72017
# 84         35951        36000        36033        35921       35811
# 159        35951        36000        36033        35921       35811
#
# [2 rows x 54 columns]

# %%
fuzzymatcher.fuzzy_left_join?
# Out:
# Signature:
# fuzzymatcher.fuzzy_left_join(
#     df_left,
#     df_right,
#     left_on,
#     right_on,
#     left_id_col=None,
#     right_id_col=None,
# )
# Docstring: <no docstring>
# File:      ~/anaconda3/lib/python3.7/site-packages/fuzzymatcher/__init__.py
# Type:      function
