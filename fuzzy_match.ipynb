# %%
import pandas as pd
df1 = pd.read_csv('PEP_2017_PEPANNRES_with_ann.csv', header=1, encoding = "ISO-8859-1")
df2 = pd.read_csv('California Cities- 2017 Pop.csv', encoding = "ISO-8859-1")

# %%
df1.head()
# Out:
#                  Id     Id2                      Geography  \
# 0  1620000US0600296  600296      Adelanto city, California
# 1  1620000US0600394  600394  Agoura Hills city, California
# 2  1620000US0600562  600562       Alameda city, California
# 3  1620000US0600674  600674        Albany city, California
# 4  1620000US0600884  600884      Alhambra city, California
#
#   April 1, 2010 - Census  April 1, 2010 - Estimates Base  \
# 0                  31765                           31760
# 1                  20330                           20330
# 2                  73812                           73812
# 3                  18539                           18541
# 4                  83089                           83117
#
#    Population Estimate (as of July 1) - 2010  \
# 0                                      31667
# 1                                      20335
# 2                                      73968
# 3                                      18570
# ...

# %%
import numpy as np
len(np.unique(df1["Geography"].values))
# Out:
# 482

# %%
df2.head()
# Out:
#     County        pol1 Population Estimate 2017  pol2  pol3    pol4  pol5  \
# 0  Alameda     Alameda                   79,177     1   1.0   15255   NaN
# 1  Alameda      Albany                   20,143     1   1.0  2017-9   NaN
# 2  Alameda    Berkeley                  122,324     1   1.0     NaN   NaN
# 3  Alameda      Dublin                   60,939     0   NaN     NaN   NaN
# 4  Alameda  Emeryville                   11,758     1   1.0   17-08   NaN
#
#   pol6       pol7       pol8  ...  ppol33  ppol34  ppol35  ppol35a  ppol41  \
# 0    2  1/18/2017  1/18/2017  ...     NaN     NaN     NaN      NaN     NaN
# 1    2  4/17/2017  4/17/2017  ...     NaN     NaN     NaN      NaN     NaN
# 2    2  6/25/2017  6/25/2017  ...  1986.0  1986.0     1.0      NaN     1.0
# 3  NaN        NaN        NaN  ...     NaN     NaN     NaN      NaN     NaN
# 4    2  1/17/2017  1/17/2017  ...     NaN     NaN     NaN      NaN     NaN
#
#    ppol42  ppol43  ppol44  ppol45 ppol45a
# ...

# %%
names1 = df1["Geography"].values
names2 = df2["pol1"].values

# %%
from fuzzywuzzy import fuzz

# %%
def match_name(name, list_names, min_score=0):
    # -1 score incase we don't get any matches
    max_score = -1
    # Returning empty name for no match as well
    max_name = ""
    # Iternating over all names in the other
    for name2 in list_names:
        #Finding fuzzy match score
        score = fuzz.ratio(name, name2)
        # Checking if we are above our threshold and have a better score
        if (score > min_score) & (score > max_score):
            max_name = name2
            max_score = score
    return (max_name, max_score)

# %%
for name in names2:
    print(name,match_name(name, names1,3))
# Out:
# Alameda ('Alameda city, California', 45)
# Albany ('Albany city, California', 41)
# Berkeley ('Berkeley city, California', 48)
# Dublin ('Dinuba city, California', 41)
# Emeryville ('Emeryville city, California', 54)
# Fremont ('Fremont city, California', 45)
# Hayward ('Hayward city, California', 45)
# Livermore ('Livermore city, California', 51)
# Newark ('Newark city, California', 41)
# Oakland ('Oakland city, California', 45)
# Piedmont ('Piedmont city, California', 48)
# Pleasanton ('Pleasanton city, California', 54)
# San Leandro ('San Leandro city, California', 56)
# Union City ('Union City city, California', 54)
# Amador City ('Amador City city, California', 56)
# Ione ('Ione city, California', 32)
# Jackson ('Jackson city, California', 45)
# Plymouth ('Plymouth city, California', 48)
# Sutter Creek ('Sutter Creek city, California', 59)
# Biggs ('Biggs city, California', 37)
# Chico ('Chico city, California', 37)
# Gridley ('Gridley city, California', 45)
# ...

# %%
for name in names1:
    print(name,match_name(name, names2,3))
# Out:
# Adelanto city, California ('California City', 50)
# Agoura Hills city, California ('Agoura Hills', 59)
# Alameda city, California ('California City', 51)
# Albany city, California ('California City', 53)
# Alhambra city, California ('California City', 50)
# Aliso Viejo city, California ('Aliso Viejo', 56)
# Alturas city, California ('California City', 51)
# Amador City city, California ('Amador City', 56)
# American Canyon city, California ('American Canyon', 64)
# Anaheim city, California ('California City', 51)
# Anderson city, California ('California City', 50)
# Angels city, California ('Angels Camp', 53)
# Antioch city, California ('California City', 51)
# Apple Valley town, California ('Apple Valley', 59)
# Arcadia city, California ('California City', 51)
# Arcata city, California ('California City', 53)
# Arroyo Grande city, California ('Arroyo Grande', 60)
# Artesia city, California ('California City', 51)
# Arvin city, California ('California City', 54)
# ...

# %%
df1["Geography"].str.split(",", n = 1, expand = True)
# Out:
#                          0            1
# 0            Adelanto city   California
# 1        Agoura Hills city   California
# 2             Alameda city   California
# 3              Albany city   California
# 4            Alhambra city   California
# 5         Aliso Viejo city   California
# 6             Alturas city   California
# 7         Amador City city   California
# 8     American Canyon city   California
# 9             Anaheim city   California
# 10           Anderson city   California
# 11             Angels city   California
# 12            Antioch city   California
# 13       Apple Valley town   California
# 14            Arcadia city   California
# 15             Arcata city   California
# 16      Arroyo Grande city   California
# 17            Artesia city   California
# 18              Arvin city   California
# 19         Atascadero city   California
# 20           Atherton town   California
# 21            Atwater city   California
# ...

# %%
names3 = df1["Geography"].str.split(",", n = 1, expand = True)[0].values
names3
# Out:
# array(['Adelanto city', 'Agoura Hills city', 'Alameda city',
#        'Albany city', 'Alhambra city', 'Aliso Viejo city', 'Alturas city',
#        'Amador City city', 'American Canyon city', 'Anaheim city',
#        'Anderson city', 'Angels city', 'Antioch city',
#        'Apple Valley town', 'Arcadia city', 'Arcata city',
#        'Arroyo Grande city', 'Artesia city', 'Arvin city',
#        'Atascadero city', 'Atherton town', 'Atwater city', 'Auburn city',
#        'Avalon city', 'Avenal city', 'Azusa city', 'Bakersfield city',
#        'Baldwin Park city', 'Banning city', 'Barstow city',
#        'Beaumont city', 'Bell city', 'Bellflower city',
#        'Bell Gardens city', 'Belmont city', 'Belvedere city',
#        'Benicia city', 'Berkeley city', 'Beverly Hills city',
#        'Big Bear Lake city', 'Biggs city', 'Bishop city',
#        'Blue Lake city', 'Blythe city', 'Bradbury city', 'Brawley city',
#        'Brea city', 'Brentwood city', 'Brisbane city', 'Buellton city',
# ...

# %%
for i,name in enumerate(names2):
    print(i,name,match_name(name, names3,3))
# Out:
# 0 Alameda ('Alameda city', 74)
# 1 Albany ('Albany city', 71)
# 2 Berkeley ('Berkeley city', 76)
# 3 Dublin ('Dublin city', 71)
# 4 Emeryville ('Emeryville city', 80)
# 5 Fremont ('Fremont city', 74)
# 6 Hayward ('Hayward city', 74)
# 7 Livermore ('Livermore city', 78)
# 8 Newark ('Newark city', 71)
# 9 Oakland ('Oakland city', 74)
# 10 Piedmont ('Piedmont city', 76)
# 11 Pleasanton ('Pleasanton city', 80)
# 12 San Leandro ('San Leandro city', 81)
# 13 Union City ('Union City city', 80)
# 14 Amador City ('Amador City city', 81)
# 15 Ione ('Ione city', 62)
# 16 Jackson ('Jackson city', 74)
# 17 Plymouth ('Plymouth city', 76)
# 18 Sutter Creek ('Sutter Creek city', 83)
# 19 Biggs ('Biggs city', 67)
# 20 Chico ('Chico city', 67)
# 21 Gridley ('Gridley city', 74)
# 22 Oroville ('Oroville city', 76)
# 23 Paradise ('Paradise town', 76)
# 24 Angels Camp ('Angels city', 64)
# 25 Colusa ('Colusa city', 71)
# 26 Williams ('Williams city', 76)
# 27 Antioch ('Antioch city', 74)
# ...

# %%
len(names2)
# Out:
# 482

# %%
len(names1)
# Out:
# 482
